# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmed-Shatla/Kalman-Filter/blob/main/Kalman_filter_1D_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![1k.png](data:image/png;base64,...)

# %%
measurements = [5., 6., 7., 9., 10.]
motion = [1., 1., 2., 1., 1.]
measurement_sig = 4.
motion_sig = 2.
mu = 0.
sig = 10000.

# %% [markdown]
# ![k2.png](data:image/png;base64,...)

# %%
def update(mean1, var1, mean2, var2):
    new_mean = float(var2 * mean1 + var1 * mean2) / (var1 + var2)
    new_var = 1./(1./var1 + 1./var2)
    return [new_mean, new_var]

# %%
def predict(mean1, var1, mean2, var2):
    new_mean = mean1 + mean2
    new_var = var1 + var2
    return [new_mean, new_var]

# %%
for i in range(len(motion)):
    [mu,sig] = update(mu,sig,measurements[i],measurement_sig)
    print(f"{i}. Update :",[mu,sig])
    [mu,sig] = predict(mu,sig,motion[i],motion_sig)
    print(f"{i}. predict :",[mu,sig])
# Out:
# 0. Update : [8.09365491547111, 2.00000142965368]
# 0. predict : [9.09365491547111, 4.00000142965368]
# 1. Update : [7.546827181307159, 2.0000003574133562]
# 1. predict : [8.546827181307158, 4.000000357413356]
# 2. Update : [7.773413556100037, 2.000000089353335]
# 2. predict : [9.773413556100037, 4.000000089353335]
# 3. Update : [9.386706773730827, 2.000000022338334]
# 3. predict : [10.386706773730827, 4.000000022338334]
# 4. Update : [10.193353386325514, 2.0000000055845835]
# 4. predict : [11.193353386325514, 4.0000000055845835]
